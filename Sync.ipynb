# %% [markdown]
# ### Descarga de Acciones

# %%
pip install yfinance
pip install fix_yahoo_finance

# %%
import pandas as pd
import yfinance as yf
import datetime as dt
from time import sleep
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')

# Soluciona problema de verificación de SSL
import ssl
ssl._create_default_https_context = ssl._create_unverified_context



import pandas_datareader as pdr
import queue


from concurrent.futures.thread import ThreadPoolExecutor

import yfinance as yf

# %%
portfolio = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']



prices = pdr.get_data_yahoo(portfolio, start = '2010-01-01', end = '2022-06-30')['Adj Close']
prices
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'T', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /usr/local/lib/python3.7/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'AMZN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /usr/local/lib/python3.7/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'PM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /usr/local/lib/python3.7/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'PXD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /usr/local/lib/python3.7/dist-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'PGR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...

# %%
weekly_prices = prices.asfreq('7D').dropna().ffill()
returns = weekly_prices.pct_change()
returns

# %%
risk_free = pdr.get_data_yahoo("^TNX", start = '2010-01-01', end = '2022-06-30')['Adj Close']
risk_free

risk_free_adjusted = risk_free/100
risk_free_adjusted

# %%
rend_2012Q1 = returns.loc["2009-12-31":"2011-12-31"]
rend_2012Q2 = returns.loc["2010-03-01":"2012-03-31"]
rend_2012Q3 = returns.loc["2010-06-01":"2012-06-30"]
rend_2012Q4 = returns.loc["2010-09-01":"2012-09-30"]
rend_2013Q1 = returns.loc["2010-12-31":"2012-12-31"]
rend_2013Q2 = returns.loc["2011-03-01":"2013-03-31"]
rend_2013Q3 = returns.loc["2011-06-01":"2013-06-30"]
rend_2013Q4 = returns.loc["2011-09-01":"2013-09-30"]

rend_2014Q1 = returns.loc["2011-12-31":"2013-12-31"]
rend_2014Q2 = returns.loc["2012-03-01":"2014-03-31"]
rend_2014Q3 = returns.loc["2012-06-01":"2014-06-30"]
rend_2014Q4 = returns.loc["2012-09-01":"2014-09-30"]

rend_2015Q1 = returns.loc["2012-12-31":"2014-12-31"]
rend_2015Q2 = returns.loc["2013-03-01":"2015-03-31"]
rend_2015Q3 = returns.loc["2013-06-01":"2015-06-30"]
rend_2015Q4 = returns.loc["2013-09-01":"2015-09-30"]

rend_2016Q1 = returns.loc["2013-12-31":"2015-12-31"]
rend_2016Q2 = returns.loc["2014-03-01":"2016-03-31"]
rend_2016Q3 = returns.loc["2014-06-01":"2016-06-30"]
rend_2016Q4 = returns.loc["2014-09-01":"2016-09-30"]

rend_2017Q1 = returns.loc["2014-12-31":"2016-12-31"]
rend_2017Q2 = returns.loc["2015-03-01":"2017-03-31"]
rend_2017Q3 = returns.loc["2015-06-01":"2017-06-30"]
rend_2017Q4 = returns.loc["2015-09-01":"2017-09-30"]

rend_2018Q1 = returns.loc["2015-12-31":"2017-12-31"]
rend_2018Q2 = returns.loc["2016-03-01":"2018-03-31"]
rend_2018Q3 = returns.loc["2016-06-01":"2018-06-30"]
rend_2018Q4 = returns.loc["2016-09-01":"2018-09-30"]

rend_2019Q1 = returns.loc["2016-01-01":"2018-12-31"]
rend_2019Q2 = returns.loc["2017-03-01":"2019-03-31"]
rend_2019Q3 = returns.loc["2017-06-01":"2019-06-30"]
rend_2019Q4 = returns.loc["2017-09-01":"2019-09-30"]

rend_2020Q1 = returns.loc["2018-01-01":"2019-12-31"]
rend_2020Q2 = returns.loc["2018-03-01":"2020-03-31"]
rend_2020Q3 = returns.loc["2018-06-01":"2020-06-30"]
rend_2020Q4 = returns.loc["2018-09-01":"2020-09-30"]

rend_2021Q1 = returns.loc["2019-01-01":"2020-12-31"]
rend_2021Q2 = returns.loc["2019-03-01":"2021-03-31"]
rend_2021Q3 = returns.loc["2019-06-01":"2021-06-30"]
rend_2021Q4 = returns.loc["2019-09-01":"2021-09-30"]

rend_2022Q1 = returns.loc["2019-12-31":"2021-12-31"]
rend_2022Q2 = returns.loc["2020-03-01":"2022-03-31"]

# %%
import pandas as pd
import yfinance as yf
import datetime as dt
from time import sleep
import numpy as np
import pandas_datareader as pdr
import matplotlib.pyplot as plt
plt.style.use('seaborn-colorblind')

import yfinance as yf

risk_free = pdr.get_data_yahoo("^TNX", start = '2010-01-01', end = '2022-06-30')['Adj Close']
risk_free

risk_free_adjusted = risk_free/100
risk_free_adjusted

rf_2012Q1 = risk_free_adjusted.loc["2011-12-30"]
rf_2012Q2 = risk_free_adjusted.loc["2012-03-30"]
rf_2012Q3 = risk_free_adjusted.loc["2012-06-29"]
rf_2012Q4 = risk_free_adjusted.loc["2012-09-28"]
rf_2013Q1 = risk_free_adjusted.loc["2012-12-31"]
rf_2013Q2 = risk_free_adjusted.loc["2013-03-28"]
rf_2013Q3 = risk_free_adjusted.loc["2013-06-28"]
rf_2013Q4 = risk_free_adjusted.loc["2013-09-30"]
rf_2014Q1 = risk_free_adjusted.loc["2013-12-30"]
rf_2014Q2 = risk_free_adjusted.loc["2014-03-31"]
rf_2014Q3 = risk_free_adjusted.loc["2014-06-30"]
rf_2014Q4 = risk_free_adjusted.loc["2014-09-30"]
rf_2015Q1 = risk_free_adjusted.loc["2014-12-30"]
rf_2015Q2 = risk_free_adjusted.loc["2015-03-31"]
rf_2015Q3 = risk_free_adjusted.loc["2015-06-30"]
rf_2015Q4 = risk_free_adjusted.loc["2015-09-30"]
rf_2016Q1 = risk_free_adjusted.loc["2015-12-30"]
rf_2016Q2 = risk_free_adjusted.loc["2016-03-31"]
rf_2016Q3 = risk_free_adjusted.loc["2016-06-30"]
rf_2016Q4 = risk_free_adjusted.loc["2016-09-30"]
rf_2017Q1 = risk_free_adjusted.loc["2016-12-30"]
rf_2017Q2 = risk_free_adjusted.loc["2017-03-31"]
rf_2017Q3 = risk_free_adjusted.loc["2017-06-30"]
rf_2017Q4 = risk_free_adjusted.loc["2017-09-29"]
rf_2018Q1 = risk_free_adjusted.loc["2017-12-29"]
rf_2018Q2 = risk_free_adjusted.loc["2018-03-29"]
rf_2018Q3 = risk_free_adjusted.loc["2018-06-29"]
rf_2018Q4 = risk_free_adjusted.loc["2018-09-28"]
rf_2019Q1 = risk_free_adjusted.loc["2018-12-31"]
rf_2019Q2 = risk_free_adjusted.loc["2019-03-29"]
rf_2019Q3 = risk_free_adjusted.loc["2019-06-28"]
rf_2019Q4 = risk_free_adjusted.loc["2019-09-30"]
rf_2020Q1 = risk_free_adjusted.loc["2019-12-30"]
rf_2020Q2 = risk_free_adjusted.loc["2020-03-31"]
rf_2020Q3 = risk_free_adjusted.loc["2020-06-30"]
rf_2020Q4 = risk_free_adjusted.loc["2020-09-30"]
rf_2021Q1 = risk_free_adjusted.loc["2020-12-30"]
rf_2021Q2 = risk_free_adjusted.loc["2021-03-31"]
rf_2021Q3 = risk_free_adjusted.loc["2021-06-30"]
rf_2021Q4 = risk_free_adjusted.loc["2021-09-30"]
rf_2022Q1 = risk_free_adjusted.loc["2021-12-30"]
rf_2022Q2 = risk_free_adjusted.loc["2022-03-31"]

# %%
def mean_var_estimates(returns, freq = None):
    if freq is not None:
        mean_estimate = np.expm1(returns.mean()*freq)
        cov_estimate = returns.cov()*freq
    else:
        mean_estimate = np.expm1(returns.mean())
        cov_estimate = returns.cov()
    return mean_estimate, cov_estimate
# media del portafolio
def port_var(weights, covariance_matrix):
    return weights.T @ covariance_matrix @ weights

# varianza del portafolio
def port_mean(weights, mean_returns):
    return mean_returns @ weights

# agregado
def portfolio_metrics(weights, mean_returns, cov_matrix):
    ret = port_mean(weights=weights, mean_returns= mean_returns)
    std = np.sqrt(port_var(weights=weights, covariance_matrix=cov_matrix))
    return ret, std
# funciones auxiliares
# Calculamos volatilidad y retorno de un portafolio
#def portfolio_metrics(weights, mean_returns, cov_matrix):
#    ret = np.sum(mean_returns * weights)
#    std = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
#    return ret, std

# armamos los portafolios random
def random_portfolios(num_port, mean_returns, cov_matrix):
    metrics = np.zeros((2,num_port))
    weights_matrix = []

    for i in range(num_port):
        weights = np.random.rand(len(mean_returns))
        #weights = np.random.()
        weights /= np.sum(weights)
        weights_matrix.append(weights)
        port_mu, port_std = portfolio_metrics(weights, mean_returns, cov_matrix)
        metrics[0,i] = port_mu
        metrics[1,i] = port_std
    return metrics, weights_matrix

# %%
from pypfopt import expected_returns
from pypfopt import risk_models

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2012Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2012Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2012Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2012Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights
yui = pd.DataFrame(weights)
yui
yui2 = yui/100

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go

start = datetime.datetime(2012, 1, 1)
end = datetime.datetime(2012, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2012Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2012Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2012Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2012Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2012, 3, 31)
end = datetime.datetime(2012, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2012Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2012Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2012Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2012Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2012, 7, 1)
end = datetime.datetime(2012, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2012Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2012Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2012Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2012Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2012, 10, 1)
end = datetime.datetime(2012, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %% [markdown]
# ## 2013

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2013Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2013Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2013Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2013Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2013, 1, 1)
end = datetime.datetime(2013, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2013Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2013Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2013Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2013Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2013, 4, 1)
end = datetime.datetime(2013, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2013Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2013Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2013Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2013Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2013, 7, 1)
end = datetime.datetime(2013, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2013Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2013Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2013Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2013Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2013, 10, 1)
end = datetime.datetime(2013, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %% [markdown]
# ## 2014

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2014Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2014Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2014Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2014Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2014, 1, 1)
end = datetime.datetime(2014, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2014Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2014Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2014Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2014Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2014, 4, 1)
end = datetime.datetime(2014, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2014Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2014Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2014Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2014Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2014, 7, 1)
end = datetime.datetime(2014, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2014Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2014Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2014Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2014Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2014, 10, 1)
end = datetime.datetime(2014, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
##2015

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2015Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2015Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2015Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2015Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 1, 1)
end = datetime.datetime(2015, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2015Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2015Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2015Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2015Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2015Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2015Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2015Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2015Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 7, 1)
end = datetime.datetime(2015, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2015Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2015Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2015Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2015Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 10, 1)
end = datetime.datetime(2015, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
##2016

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2016Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2016Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2016Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2016Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2016, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2016Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2016Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2016Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2016Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2016, 4, 1)
end = datetime.datetime(2016, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2016Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2016Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2016Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2016Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2016, 7, 1)
end = datetime.datetime(2016, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2016Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2016Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2016Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2016Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2016, 10, 1)
end = datetime.datetime(2016, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %% [markdown]
# ## 2017

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2017Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2017Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2017Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2017Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2017, 1, 1)
end = datetime.datetime(2017, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2017Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2017Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2017Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2017Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2017, 4, 1)
end = datetime.datetime(2017, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2017Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2017Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2017Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2017Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2017, 7, 1)
end = datetime.datetime(2017, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2017Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2017Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2017Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2017Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2017, 10, 1)
end = datetime.datetime(2017, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %% [markdown]
# ##2018

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2018Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2018Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2018Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2018Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2018, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2018Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2018Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2018Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2018Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2018, 4, 1)
end = datetime.datetime(2018, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2018Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2018Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2018Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2018Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2018, 7, 1)
end = datetime.datetime(2018, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2018Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2018Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2018Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2018Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2018, 10, 1)
end = datetime.datetime(2018, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %% [markdown]
# # 2019

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2019Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2019Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2019Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2019Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2019, 1, 1)
end = datetime.datetime(2019, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2019Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2019Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2019Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2019Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2019, 4, 1)
end = datetime.datetime(2019, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2019Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2019Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2019Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2019Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2019, 7, 1)
end = datetime.datetime(2019, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2019Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2019Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2019Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2019Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2019, 10, 1)
end = datetime.datetime(2019, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %% [markdown]
# # 2020

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2020Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2020Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2020Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2020Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2020, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2020Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2020Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2020Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2020Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2020, 4, 1)
end = datetime.datetime(2020, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2020Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2020Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2020Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2020Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2020, 7, 1)
end = datetime.datetime(2020, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2020Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2020Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2020Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2020Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2020, 10, 1)
end = datetime.datetime(2020, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %% [markdown]
# # 2021

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2021Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2021Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2021Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2021Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2021, 1, 1)
end = datetime.datetime(2021, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2021Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2021Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2021Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2021Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2021, 4, 1)
end = datetime.datetime(2021, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2021Q3, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2021Q3, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2021Q3, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2021Q3 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2021, 7, 1)
end = datetime.datetime(2021, 9, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2021Q4, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2021Q4, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2021Q4, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2021Q4 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2021, 10, 1)
end = datetime.datetime(2021, 12, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %% [markdown]
# # 2022

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2022Q1, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2022Q1, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2022Q1, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2022Q1 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2022, 1, 1)
end = datetime.datetime(2022, 3, 31)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")













#codigo sintetizado
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
start = datetime.datetime(2015, 4, 1)
end = datetime.datetime(2015, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")

# %%
df_sample = pd.DataFrame()
df_sample['Mu'] = mean_var_estimates(returns = rend_2022Q2, freq = 52)[0]
df_sample['Sigma'] = np.sqrt(np.diag(mean_var_estimates(returns = rend_2022Q2, freq = 52)[1]))
cov_matrix = mean_var_estimates(returns = rend_2022Q2, freq = 52)[1]
df_sample

# %%
fig, ax = plt.subplots(figsize = (12,12))
df_sample.plot(x='Sigma', y = 'Mu', kind = 'scatter', ax = ax)
plt.title('Mean-Variance Analysis')
plt.ylabel('Retorno esperado')
plt.xlabel('Volatilidad')

for k, v in df_sample.iterrows():
    ax.annotate(k,v[::-1])

# %%
n_port = 10000
metrics, weights_matrix = random_portfolios(n_port, df_sample['Mu'], cov_matrix)

plt.figure(figsize=(16,9))
plt.plot(metrics[1,:], metrics[0,:], 'o')
plt.scatter(df_sample['Sigma'], df_sample['Mu'], marker = 'x', color = 'r')
plt.title('Random Portfolios')
plt.xlabel('Volatilidad anualizada')
plt.ylabel('Retorno esperado anualizado')
plt.show()

# %%
# Portafolio de Mínima Varianza
import cvxopt as opt

opt.solvers.options['show_progress'] = False
# minimize    (1/2)*x'*P*x + q'*x
#        subject to  G*x <= h
#                    A*x = b.

n = len(df_sample['Mu'])

# Función objetivo
P = opt.matrix(cov_matrix.to_numpy())
q = opt.matrix(np.zeros((n,1)))

# Restricciones
## de desigualdad ( G [nxn] >= h [nx1])
G = opt.matrix(-np.eye(n)) # matrix de n x n con 1's en la diagonal
h = opt.matrix(np.zeros((n,1)))
## de igualdad ( A [1xn] = b [1x1])
A = opt.matrix(1.0,(1,n))
b = opt.matrix(1.0)

solution = opt.solvers.qp(P,q,G,h,A,b)
mvg_pond = np.array(solution['x'])

mvg_ret = np.asmatrix(df_sample['Mu']) * np.asmatrix(mvg_pond)
mvg_std = np.sqrt(np.asmatrix(mvg_pond).T * np.asmatrix(cov_matrix) * np.asmatrix(mvg_pond))


print("El retorno esperado de la cartera es: %2.2f%%" % (mvg_ret*100))
print("La volatilidad de la cartera es: %2.2f%%" % (mvg_std*100))
pd.DataFrame(np.round(mvg_pond*100,1), index = df_sample.index)

# %%
# portafolio de Maximum Sharpe
# cuando hacemos el max sharpe lo que hacemos es maximizar precio por riesgo
# max{(mu_port - risk_free)/sigma_port}
import scipy.optimize as sco
from scipy import stats

r_f = rf_2022Q2 # definimos a la risk free, la tasa de hoy en día.

def max_SR(mean_returns, covariance_matrix, risk_free):
    n = len(mean_returns)

    def get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free):
        weights = np.array(weights)
        ret = np.sum(np.array(mean_returns) * weights)
        vol = np.sqrt(np.dot(weights.T, np.dot(np.array(covariance_matrix), weights)))
        sr = (ret - risk_free)/vol
        return np.array([ret, vol, sr])

    # ¿por qué buscamos un negative Sharpe Ratio?
    def neg_sr(weights, mean_returns, covariance_matrix, risk_free):
        return -get_ret_vol_sr(weights, mean_returns, covariance_matrix, risk_free)[2]

    # hay que construir las restricciones------->son 2
    # fully invested
    def check_sum(weights):
        return np.sum(weights) - 1
    # constraints = tipo -> ecuacion, funcion específica
    # estose hace así por el optimizador que usamos
    cons = ({'type':'eq','fun':check_sum})

    # long only
    boundaries = ((0,1),)*n

    # initial guess
    init_guess = [1/n]*n # repite n veces 1 sobre n

    # podemos optimizar
    optimizacion = sco.minimize(neg_sr, init_guess, method='SLSQP', bounds= boundaries,
                                constraints = cons, args = (mean_returns,covariance_matrix, risk_free),
                               options = {'disp': False})
    weights = pd.Series(np.round(optimizacion.x*100,1), index = mean_returns.index)
    return weights, -optimizacion.fun
weights, fun = max_SR(df_sample['Mu'], cov_matrix, r_f)
weights

# %%
fun

# %%
#codigo sintetizado
yui = pd.DataFrame(weights)
yui
yui2 = yui/100
import numpy as np
import pandas as pd
import pandas_datareader as web
import plotly.express as px
import pandas_datareader
import datetime
import pandas_datareader.data as web
import plotly.graph_objects as go

start = datetime.datetime(2022, 4, 1)
end = datetime.datetime(2022, 6, 30)
T = web.DataReader('T','yahoo',start,end)
AMZN = web.DataReader('AMZN','yahoo',start,end)
PM = web.DataReader('PM','yahoo',start,end)
PXD = web.DataReader('PXD','yahoo',start,end)
PGR = web.DataReader('PGR','yahoo',start,end)
ABT = web.DataReader('ABT','yahoo',start,end)
MMM = web.DataReader('MMM','yahoo',start,end)
ADBE = web.DataReader('ADBE','yahoo',start,end)
AVY = web.DataReader('AVY','yahoo',start,end)
CBRE = web.DataReader('CBRE','yahoo',start,end)
AEP = web.DataReader('AEP','yahoo',start,end)
IBM = web.DataReader('IBM','yahoo',start,end)
PFE = web.DataReader('PFE','yahoo',start,end)
NEM = web.DataReader('NEM','yahoo',start,end)
MCD = web.DataReader('MCD','yahoo',start,end)
JPM = web.DataReader('JPM','yahoo',start,end)
AIG = web.DataReader('AIG','yahoo',start,end)
WMT = web.DataReader('WMT','yahoo',start,end)
VZ = web.DataReader('VZ','yahoo',start,end)
CSCO = web.DataReader('CSCO','yahoo',start,end)

##Banchmarks for comparision
SPY = web.DataReader('SPY','yahoo',start,end)
VOO = web.DataReader('VOO','yahoo',start,end)
IVV = web.DataReader('IVV','yahoo',start,end)
SWPPX = web.DataReader('SWPPX','yahoo',start,end)


labels = portfolio
allocation_pct1 = pd.DataFrame(np.round(mvg_pond,1), index = df_sample.index)[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct1)])
fig.update_layout(title="Portfolio Asset Allocation Min Var")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc1 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct1):
  df['Value'] = alloc1*init_investment*df['Cum Return']
init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals1 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val1 = pd.concat(all_vals1, axis=1)
portfolio_val1.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val1['Portfolio Min Var'] = round(portfolio_val1.sum(axis=1))
portfolio_val1['Cum Return'] = portfolio_val1['Portfolio Min Var']/portfolio_val1.iloc[0]['Portfolio Min Var']
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
portfolio_val1['Cum Return %'] = (portfolio_val1['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100
labels = portfolio
allocation_pct2 = yui2[0].tolist()
fig = go.Figure(data=[go.Pie(labels=labels, values=allocation_pct2)])
fig.update_layout(title="Portfolio Asset Allocation Max Sharpe")
fig.show()
for df in (T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO,SPY,VOO,IVV,SWPPX):
  df['Cum Return'] = df['Adj Close']/df.iloc[0]['Adj Close']
init_investment = 10000
for df, alloc2 in zip((T, AMZN,PM, PXD, PGR, ABT, MMM, ADBE, AVY, CBRE, AEP, IBM,PFE, NEM, MCD
            , JPM, AIG, WMT, VZ, CSCO), allocation_pct2):
  df['Value'] = alloc2*init_investment*df['Cum Return']

init_investment = 10000
SPY['SPY Total'] = init_investment*SPY['Cum Return']
SPY['SPY Total'] = round(SPY['SPY Total'])
VOO['VOO Total'] = init_investment*VOO['Cum Return']
VOO['VOO Total'] = round(VOO['VOO Total'])
IVV['IVV Total'] = init_investment*IVV['Cum Return']
IVV['IVV Total'] = round(IVV['IVV Total'])
SWPPX['SWPPX Total'] = init_investment*SWPPX['Cum Return']
SWPPX['SWPPX Total'] = round(SWPPX['SWPPX Total'])

all_vals2 = [T['Value'], AMZN['Value'],PM['Value'], PXD['Value'], PGR['Value'], ABT['Value'], MMM['Value'], ADBE['Value'], AVY['Value'], CBRE['Value'], AEP['Value'], IBM['Value'],PFE['Value'], NEM['Value'], MCD['Value']
            , JPM['Value'], AIG['Value'], WMT['Value'], VZ['Value'], CSCO['Value']]
portfolio_val2 = pd.concat(all_vals2, axis=1)
portfolio_val2.columns = ['T', 'AMZN','PM', 'PXD', 'PGR', 'ABT', 'MMM', 'ADBE', 'AVY', 'CBRE', 'AEP', 'IBM','PFE', 'NEM', 'MCD'
            , 'JPM', 'AIG', 'WMT', 'VZ', 'CSCO']
portfolio_val2['Portfolio Max Sharpe'] = round(portfolio_val2.sum(axis=1))
portfolio_val2['Cum Return'] = portfolio_val2['Portfolio Max Sharpe']/portfolio_val2.iloc[0]['Portfolio Max Sharpe']
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
portfolio_val2['Cum Return %'] = (portfolio_val2['Cum Return'] - 1) * 100
SPY['Cum Return %'] = (SPY['Cum Return'] - 1) * 100
VOO['Cum Return %'] = (VOO['Cum Return'] - 1) * 100
IVV['Cum Return %'] = (IVV['Cum Return'] - 1) * 100
SWPPX['Cum Return %'] = (SWPPX['Cum Return'] - 1) * 100

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=portfolio_val1.index, y=portfolio_val1['Portfolio Min Var'], name='Portfolio Min Var'))
fig.add_trace(go.Scatter(x=portfolio_val2.index, y=portfolio_val2['Portfolio Max Sharpe'], name='Portfolio Max Sharpe'))
fig.add_trace(go.Scatter(x=SPY.index, y=SPY['SPY Total'],name='SPY Total'))
fig.add_trace(go.Scatter(x=IVV.index, y=IVV['IVV Total'],name='IVV Total'))
fig.add_trace(go.Scatter(x=VOO.index, y=VOO['VOO Total'],name='VOO Total'))
fig.add_trace(go.Scatter(x=SWPPX.index, y=SWPPX['SWPPX Total'],name='SWPPX Total'))
fig.update_layout(title="Portfolio Value")
